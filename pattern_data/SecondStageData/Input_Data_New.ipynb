# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_normal = pd.read_csv(r"C:\Users\user\Desktop\SEM 8\Project Sarjana Muda (PSM)\THESIS PROGRESS\Control Chart Pattern Recognition (CCPR) Project\pattern_data\FirstStageData\Normal_Pattern.csv")
df_normal['Class'] =1
df_normal
# Out:
#        T1 New    T2 New    T3 New    T4 New    T5 New    T6 New    T7 New  \
# 0    0.240563  0.087118 -0.270576 -0.828400 -0.267872 -0.045424  0.116035
# 1   -0.521809 -0.551405 -0.099760  0.331820  1.000000  0.189424  0.623210
# 2   -0.353543  0.040962  0.495918 -0.066714 -0.130652 -0.870805  0.109598
# 3   -0.467600 -0.562362 -0.134950  0.433643 -0.029998  0.064815  0.464542
# 4    0.436794  0.487983 -0.061344  0.021931  0.148896 -0.756314  0.224792
# ..        ...       ...       ...       ...       ...       ...       ...
# 495 -0.235256  0.006082 -0.557384 -0.567269 -0.456768 -0.703902 -0.592641
# 496 -0.004544 -0.755045  0.344115 -0.975017  0.437366 -0.324837 -0.194212
# 497  1.000000 -0.359539  0.582837 -0.056276  0.305547  0.233307 -0.235969
# 498  0.306257  0.799148 -0.012704 -0.216978 -1.000000 -0.018756 -0.257978
# 499  0.470234  0.713677  0.716057  0.494034 -0.105225  0.433985 -0.426891
#
#        T8 New    T9 New   T10 New  ...   T24 New   T25 New   T26 New  \
# ...

# %%
df_stratification = pd.read_csv(r"C:\Users\user\Desktop\SEM 8\Project Sarjana Muda (PSM)\THESIS PROGRESS\Control Chart Pattern Recognition (CCPR) Project\pattern_data\FirstStageData\Stratification_Pattern.csv")
df_stratification['Class'] =2
df_stratification
# Out:
#        T1 New    T2 New    T3 New    T4 New    T5 New    T6 New    T7 New  \
# 0   -0.003289  0.390997  0.171126  0.286586  0.276758 -0.527836 -0.301423
# 1    0.498556  0.276222  0.393746  0.369894  0.032683  0.334924 -0.220134
# 2    0.062883  0.042067  0.331089  0.206384 -0.244961  0.465989 -0.180835
# 3    0.306590  0.480933  0.402445  0.631884  0.224877 -0.308558  0.233818
# 4   -1.000000  0.000522 -0.277067 -0.203811  0.529109  0.184230  0.209686
# ..        ...       ...       ...       ...       ...       ...       ...
# 495 -0.212908 -0.133671 -0.314870 -0.127554  0.544125 -0.400930 -0.786532
# 496  0.344363  0.423604 -0.009300 -0.131545  0.450104 -0.048924 -0.403130
# 497 -0.299952  0.028001 -0.192595  0.261912 -0.111682  0.242619 -0.016882
# 498  0.758527  0.181678 -0.076661 -0.336512 -0.559652 -0.177007  0.230374
# 499  0.454108  0.071238  0.567050 -0.273543  0.455202  0.055207  0.497645
#
#        T8 New    T9 New   T10 New  ...   T24 New   T25 New   T26 New  \
# ...

# %%
df_systematic = pd.read_csv(r"C:\Users\user\Desktop\SEM 8\Project Sarjana Muda (PSM)\THESIS PROGRESS\Control Chart Pattern Recognition (CCPR) Project\pattern_data\FirstStageData\Systematic_Pattern.csv")
df_systematic['Class'] =3
df_systematic
# Out:
#        T1 New    T2 New    T3 New    T4 New    T5 New    T6 New    T7 New  \
# 0   -0.092896  0.109470 -0.233439  0.588054 -0.127231  0.500024 -0.289252
# 1   -0.559225  0.417050 -0.533873  0.261728 -0.280451 -0.012319 -0.036693
# 2   -0.115904  0.636847 -0.194703  0.245325 -0.447048  0.355856 -0.184689
# 3   -0.235260  0.443259 -0.002825  1.000000 -0.294400  0.054768 -0.998170
# 4   -0.272731  0.202565 -0.038721  0.113443 -0.501405 -0.016676 -0.297845
# ..        ...       ...       ...       ...       ...       ...       ...
# 495 -0.476164  0.240348 -0.244977  0.139589  0.001784  0.238184 -0.542083
# 496 -0.024762  0.364193 -0.173290  0.179459 -0.231616  0.267118 -0.109050
# 497 -0.530823  0.328086 -0.340977 -0.085843 -0.163995 -0.079098 -0.589160
# 498  0.195066  0.225310 -0.422310  0.213333 -0.173204  0.369671 -0.781873
# 499  0.088247  0.534428 -0.136858  0.574506  0.565146  0.375376 -0.085579
#
#        T8 New    T9 New   T10 New  ...   T24 New   T25 New   T26 New  \
# ...

# %%
df_cyclic = pd.read_csv(r"C:\Users\user\Desktop\SEM 8\Project Sarjana Muda (PSM)\THESIS PROGRESS\Control Chart Pattern Recognition (CCPR) Project\pattern_data\FirstStageData\Cyclic_Pattern.csv")
df_cyclic['Class'] =4
df_cyclic.head(2)
# Out:
#      T1 New    T2 New    T3 New    T4 New    T5 New    T6 New    T7 New  \
# 0 -0.051489  0.379123  0.370065  0.012610 -0.195528 -0.254317 -0.215299
# 1  0.168370  0.536761  0.546238  0.045903 -0.329853 -0.363315 -0.339354
#
#      T8 New    T9 New   T10 New  ...   T24 New   T25 New   T26 New   T27 New  \
# 0  0.379681  0.339822  0.278485  ... -0.485020  0.306887  1.000000  0.885563
# 1 -0.330359 -0.277078  0.296736  ...  0.420171  0.957437  0.477717  0.537541
#
#     T28 New   T29 New   T30 New   T31 New   T32 New  Class
# 0  0.179773  0.107098 -0.447685 -0.959312  0.338443      4
# 1  0.327193 -0.140780 -0.816536 -0.542394  0.556329      4
#
# [2 rows x 33 columns]

# %%
df_uptrend = pd.read_csv(r"C:\Users\user\Desktop\SEM 8\Project Sarjana Muda (PSM)\THESIS PROGRESS\Control Chart Pattern Recognition (CCPR) Project\pattern_data\FirstStageData\Uptrend_Pattern.csv")
df_uptrend['Class'] =5
df_uptrend.head(2)
# Out:
#      T1 New    T2 New    T3 New    T4 New    T5 New    T6 New    T7 New  \
# 0 -0.861709 -0.826938 -0.787119 -1.000000 -0.629467 -0.617531 -0.524090
# 1 -1.000000 -0.902072 -0.915705 -0.690685 -0.565176 -0.569277 -0.475814
#
#      T8 New    T9 New   T10 New  ...   T24 New   T25 New   T26 New   T27 New  \
# 0 -0.757571 -0.456248 -0.555351  ...  0.425642  0.188983  0.472187  0.377563
# 1 -0.563570 -0.390356 -0.135982  ...  0.558558  0.426907  0.617817  0.617265
#
#     T28 New   T29 New   T30 New   T31 New  T32 New  Class
# 0  0.445428  0.615093  0.721172  1.000000  0.95175      5
# 1  0.787743  0.521995  0.758823  0.878377  1.00000      5
#
# [2 rows x 33 columns]

# %%
df_downtrend = pd.read_csv(r"C:\Users\user\Desktop\SEM 8\Project Sarjana Muda (PSM)\THESIS PROGRESS\Control Chart Pattern Recognition (CCPR) Project\pattern_data\FirstStageData\Downtrend_Pattern.csv")
df_downtrend['Class'] =6
df_downtrend.head(2)
# Out:
#      T1 New    T2 New    T3 New    T4 New    T5 New    T6 New    T7 New  \
# 0  0.962967  0.993216  1.000000  0.529793  0.699011  0.652561  0.460136
# 1  1.000000  0.770424  0.716262  0.573670  0.743555  0.611602  0.298111
#
#      T8 New    T9 New   T10 New  ...   T24 New   T25 New   T26 New   T27 New  \
# 0  0.341078  0.212551  0.357403  ... -0.348708 -0.694743 -0.648797 -0.609292
# 1  0.522269  0.416797  0.683059  ... -0.480862 -0.504245 -0.573123 -0.359465
#
#     T28 New   T29 New   T30 New   T31 New   T32 New  Class
# 0 -0.877617 -0.886329 -1.000000 -0.908548 -0.898277      6
# 1 -0.710389 -0.661581 -0.709579 -1.000000 -0.976223      6
#
# [2 rows x 33 columns]

# %%
df_upshift = pd.read_csv(r"C:\Users\user\Desktop\SEM 8\Project Sarjana Muda (PSM)\THESIS PROGRESS\Control Chart Pattern Recognition (CCPR) Project\pattern_data\FirstStageData\Upshift_Pattern.csv")
df_upshift['Class'] = 7
df_upshift.head(2)
# Out:
#      T1 New    T2 New    T3 New    T4 New    T5 New   T6 New    T7 New  \
# 0 -0.109101 -0.024877 -0.505719 -0.773657 -0.422544  0.04222 -1.000000
# 1 -0.693161  0.189964 -0.089917  0.040598 -0.445954 -1.00000 -0.294565
#
#      T8 New    T9 New   T10 New  ...   T24 New   T25 New   T26 New   T27 New  \
# 0 -0.780021  0.002704 -0.118997  ...  0.304277  1.000000  0.640818  0.095812
# 1 -0.251261 -0.652510 -0.487655  ... -0.100802 -0.225587  0.607852 -0.035761
#
#     T28 New   T29 New   T30 New   T31 New   T32 New  Class
# 0  0.372829 -0.454224  0.181870  0.586939  0.498217      7
# 1  1.000000  0.569160  0.039322  0.526652  0.552577      7
#
# [2 rows x 33 columns]

# %%
df_downshift = pd.read_csv(r"C:\Users\user\Desktop\SEM 8\Project Sarjana Muda (PSM)\THESIS PROGRESS\Control Chart Pattern Recognition (CCPR) Project\pattern_data\FirstStageData\Downshift_Pattern.csv")
df_downshift['Class'] = 8
df_downshift.head(2)
# Out:
#      T1 New    T2 New    T3 New    T4 New    T5 New    T6 New    T7 New  \
# 0  0.858319  0.086768  0.298526  0.091276  0.689097  0.929255  1.000000
# 1 -0.303257  0.206759  0.055890  0.285351  1.000000  0.257715  0.234397
#
#      T8 New    T9 New   T10 New  ...   T24 New   T25 New   T26 New   T27 New  \
# 0  0.784311  0.514137  0.018847  ... -0.178345  0.367527 -0.231852 -0.396762
# 1  0.366900  0.085159  0.649768  ... -0.020864 -0.538417 -0.707403 -0.842928
#
#     T28 New   T29 New   T30 New   T31 New   T32 New  Class
# 0 -0.421318 -0.453021 -1.000000 -0.913490 -0.712631      8
# 1  0.207005 -0.874916 -0.802321 -0.878559 -0.218507      8
#
# [2 rows x 33 columns]

# %%
df = pd.concat([df_normal,df_stratification,df_systematic,df_cyclic,df_uptrend,df_downtrend,df_upshift,df_downshift], ignore_index= True, axis = 0)
df
# Out:
#         T1 New    T2 New    T3 New    T4 New    T5 New    T6 New    T7 New  \
# 0     0.240563  0.087118 -0.270576 -0.828400 -0.267872 -0.045424  0.116035
# 1    -0.521809 -0.551405 -0.099760  0.331820  1.000000  0.189424  0.623210
# 2    -0.353543  0.040962  0.495918 -0.066714 -0.130652 -0.870805  0.109598
# 3    -0.467600 -0.562362 -0.134950  0.433643 -0.029998  0.064815  0.464542
# 4     0.436794  0.487983 -0.061344  0.021931  0.148896 -0.756314  0.224792
# ...        ...       ...       ...       ...       ...       ...       ...
# 3995  0.735109  0.270945  0.089828  0.059513  0.275085  0.541770  0.517997
# 3996  0.203038  0.301488  0.583029  0.849397  0.901300  1.000000  0.179711
# 3997  0.557385  0.701922  0.686653 -0.024438  0.369661  0.503083  0.595111
# 3998  0.556143  0.014731  0.283951  0.955454  0.261911  0.030261  0.369751
# 3999  0.233266  0.134307  0.046847  0.207484 -0.106375 -0.637818 -0.022043
#
# ...

# %%
df.to_csv(r"C:\Users\user\Desktop\SEM 8\Project Sarjana Muda (PSM)\THESIS PROGRESS\Control Chart Pattern Recognition (CCPR) Project\LVQ Algorithm (Matlab)\Exp 1 (Epoch 10)\Input_data_9.csv",index=False)
